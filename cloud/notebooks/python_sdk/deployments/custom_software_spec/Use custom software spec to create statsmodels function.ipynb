# %% [markdown]
# # Use custom software_spec to create statsmodels function describing data with `ibm-watson-machine-learning`

# %% [markdown]
# This notebook demonstrates how to deploy in Watson Machine Learning service a python function with `statsmodel` which requires to create custom software specification using conda yaml file with all required libraries.
# Some familiarity with bash is helpful. This notebook uses Python 3.9 with statsmodel.
#
#
# ## Learning goals
#
# The learning goals of this notebook are:
#
# -  Working with the Watson Machine Learning instance
# -  Creating custom software specification
# -  Online deployment of python function
# -  Scoring data using deployed function
#
# ## Contents
#
# This notebook contains the following parts:
#
# 1.	[Setup](#setup)
# 2.  [Function creation](#create)
# 3.	[Function upload](#upload)
# 4.	[Web service creation](#deploy)
# 5.	[Scoring](#score)
# 6.  [Clean up](#cleanup)
# 7.	[Summary and next steps](#summary)

# %% [markdown]
# <a id="setup"></a>
# ## 1. Set up the environment
#
# Before you use the sample code in this notebook, you must perform the following setup tasks:
#
# -  Create a <a href="https://console.ng.bluemix.net/catalog/services/ibm-watson-machine-learning/" target="_blank" rel="noopener no referrer">Watson Machine Learning (WML) Service</a> instance (a free plan is offered and information about how to create the instance can be found <a href=" https://dataplatform.cloud.ibm.com/docs/content/wsj/analyze-data/ml-service-instance.html?context=analytics" target="_blank" rel="noopener no referrer">here</a>).

# %% [markdown]
# ### Connection to WML
#
# Authenticate the Watson Machine Learning service on IBM Cloud. You need to provide platform `api_key` and instance `location`.
#
# You can use [IBM Cloud CLI](https://cloud.ibm.com/docs/cli/index.html) to retrieve platform API Key and instance location.
#
# API Key can be generated in the following way:
# ```
# ibmcloud login
# ibmcloud iam api-key-create API_KEY_NAME
# ```
#
# In result, get the value of `api_key` from the output.
#
#
# Location of your WML instance can be retrieved in the following way:
# ```
# ibmcloud login --apikey API_KEY -a https://cloud.ibm.com
# ibmcloud resource service-instance WML_INSTANCE_NAME
# ```
#
# In result, get the value of `location` from the output.

# %% [markdown]
# **Tip**: Your `Cloud API key` can be generated by going to the [**Users** section of the Cloud console](https://cloud.ibm.com/iam#/users). From that page, click your name, scroll down to the **API Keys** section, and click **Create an IBM Cloud API key**. Give your key a name and click **Create**, then copy the created key and paste it below. You can also get a service specific url by going to the [**Endpoint URLs** section of the Watson Machine Learning docs](https://cloud.ibm.com/apidocs/machine-learning).  You can check your instance location in your  <a href="https://console.ng.bluemix.net/catalog/services/ibm-watson-machine-learning/" target="_blank" rel="noopener no referrer">Watson Machine Learning (WML) Service</a> instance details.
#
# You can also get service specific apikey by going to the [**Service IDs** section of the Cloud Console](https://cloud.ibm.com/iam/serviceids).  From that page, click **Create**, then copy the created key and paste it below.
#
# **Action**: Enter your `api_key` and `location` in the following cell.

# %%
api_key = 'PASTE YOUR PLATFORM API KEY HERE'
location = 'PASTE YOUR INSTANCE LOCATION HERE'

# %%
wml_credentials = {
    "apikey": api_key,
    "url": 'https://' + location + '.ml.cloud.ibm.com'
}

# %% [markdown]
# ### Install and import the `ibm-watson-machine-learning` package
# **Note:** `ibm-watson-machine-learning` documentation can be found <a href="https://ibm.github.io/watson-machine-learning-sdk//" target="_blank" rel="noopener no referrer">here</a>.

# %%
# !pip install -U ibm-watson-machine-learning

# %%
from ibm_watson_machine_learning import APIClient

client = APIClient(wml_credentials)

# %% [markdown]
# ### Working with spaces
#
# First, create a space that will be used for your work. If you do not have space already created, you can use [Deployment Spaces Dashboard](https://dataplatform.cloud.ibm.com/ml-runtime/spaces?context=cpdaas) to create one.
#
# - Click New Deployment Space
# - Create an empty space
# - Select Cloud Object Storage
# - Select Watson Machine Learning instance and press Create
# - Copy `space_id` and paste it below
#
# **Tip**: You can also use SDK to prepare the space for your work. More information can be found [here](https://github.com/IBM/watson-machine-learning-samples/blob/master/cloud/notebooks/python_sdk/instance-management/Space%20management.ipynb).
#
# **Action**: Assign space ID below

# %%
space_id = 'PASTE YOUR SPACE ID HERE'

# %% [markdown]
# You can use `list` method to print all existing spaces.

# %%
client.spaces.list(limit=10)

# %% [markdown]
# To be able to interact with all resources available in Watson Machine Learning, you need to set **space** which you will be using.

# %%
client.set.default_space(space_id)
# Out:
# 'SUCCESS'

# %% [markdown]
# <a id="create"></a>
# ## 2. Create function
#
# In this section you will learn how to create deployable function
# with statsmodels module calculating describition of a given data.
# **Hint**: To install statsmodels execute `!pip install statsmodels`.

# %% [markdown]
# #### Create deploayable callable which uses stsmodels library

# %%
def deployable_callable():
    """
    Deployable python function with score
    function implemented.
    """
    try:
        from statsmodels.stats.descriptivestats import describe
    except ModuleNotFoundError as e:
        print(f"statsmodels not installed: {str(e)}")
        
    def score(payload):
        """
        Score method.
        """
        try:
            data = payload['input_data'][0]['values']
            return {
                'predictions': [
                    {'values': str(describe(data))}
                ]
            }
        except Exception as e:
            return {'predictions': [{'values': [repr(e)]}]}
        
    return score

# %% [markdown]
# ####  Test callable locally
#
# **Hint**: To install numpy execute `!pip install numpy`.

# %%
import numpy as np

data = np.random.randn(10, 10)
data_description = deployable_callable()({
    "input_data": [{
        "values" : data
    }]
})

print(data_description["predictions"][0]["values"])
# Out:
#                           0          1          2          3          4  \
# nobs              10.000000  10.000000  10.000000  10.000000  10.000000
# missing            0.000000   0.000000   0.000000   0.000000   0.000000
# mean               0.226671   0.118863   0.296608   0.018030  -0.059889
# std_err            0.078214   0.109682   0.077958   0.069102   0.099104
# upper_ci           0.379969   0.333837   0.449404   0.153467   0.134352
# lower_ci           0.073374  -0.096110   0.143813  -0.117407  -0.254130
# std                0.782143   1.096823   0.779584   0.691019   0.991042
# iqr                1.138703   0.979375   1.111591   0.625231   1.315194
# iqr_normal         0.844122   0.726012   0.824023   0.463485   0.974954
# mad                0.623878   0.774813   0.618962   0.513830   0.799944
# mad_normal         0.781915   0.971084   0.775754   0.643991   1.002581
# coef_var           3.450557   9.227584   2.628330  38.326234 -16.547990
# range              2.289961   3.407891   2.370988   2.429216   3.152545
# max                1.216507   1.544682   1.624286   1.266127   1.517858
# min               -1.073454  -1.863208  -0.746702  -1.163089  -1.634687
# skew              -0.180136  -0.472191   0.300966   0.263092   0.206849
# kurtosis           1.900409   2.384448   1.984736   2.702869   2.043656
# jarque_bera        0.557873   0.529483   0.580451   0.152149   0.452392
# jarque_bera_pval   0.756588   0.767404   0.748095   0.926747   0.797562
# mode              -1.073454  -1.863208  -0.746702  -1.163089  -1.634687
# mode_freq          0.100000   0.100000   0.100000   0.100000   0.100000
# median             0.131746   0.126305   0.196596  -0.075777  -0.289048
# 1%                -1.035160  -1.819212  -0.736463  -1.097474  -1.557357
# 5%                -0.881982  -1.643226  -0.695507  -0.835012  -1.248039
# 10%               -0.690509  -1.423244  -0.644312  -0.506934  -0.861391
# 25%               -0.265950  -0.093626  -0.179451  -0.372709  -0.669090
# 50%                0.131746   0.126305   0.196596  -0.075777  -0.289048
# 75%                0.872753   0.885749   0.932140   0.252522   0.646103
# 90%                1.207454   1.400947   1.147246   0.910790   1.227843
# 95%                1.211980   1.472815   1.385766   1.088459   1.372850
# 99%                1.215602   1.530309   1.576582   1.230594   1.488856
#
#                           5          6          7          8          9
# nobs              10.000000  10.000000  10.000000  10.000000  10.000000
# missing            0.000000   0.000000   0.000000   0.000000   0.000000
# mean              -0.483244  -0.254453   0.058877   0.426315   0.070967
# std_err            0.096181   0.121981   0.067393   0.132276   0.142787
# upper_ci          -0.294733  -0.015374   0.190965   0.685572   0.350825
# lower_ci          -0.671756  -0.493532  -0.073210   0.167058  -0.208891
# std                0.961811   1.219812   0.673929   1.322764   1.427874
# iqr                0.702320   1.694391   1.086336   0.818691   2.260862
# iqr_normal         0.520631   1.256054   0.805302   0.606896   1.675980
# mad                0.595403   0.992851   0.548831   0.775163   1.241234
# mad_normal         0.746228   1.244354   0.687858   0.971523   1.555656
# coef_var          -1.990319  -4.793857  11.446314   3.102789  20.120208
# range              3.290262   3.729499   2.020311   4.731702   4.155165
# max                0.264072   1.728591   1.288685   3.818537   2.356818
# min               -3.026190  -2.000908  -0.731626  -0.913165  -1.798347
# skew              -2.016374   0.280287   0.361658   1.723070   0.344541
# kurtosis           6.145500   1.926644   2.092429   5.591678   1.669951
# jarque_bera       10.898847   0.610973   0.561196   7.746946   0.934943
# jarque_bera_pval   0.004299   0.736765   0.755332   0.020786   0.626585
# mode              -3.026190  -2.000908  -0.731626  -0.913165  -1.798347
# mode_freq          0.100000   0.100000   0.100000   0.100000   0.100000
# median            -0.281243  -0.424602  -0.082306   0.343253  -0.500832
# 1%                -2.818282  -1.945829  -0.727344  -0.906817  -1.742649
# 5%                -1.986648  -1.725515  -0.710218  -0.881427  -1.519857
# 10%               -0.947106  -1.450121  -0.688811  -0.849689  -1.241366
# 25%               -0.631465  -1.180252  -0.542524  -0.252573  -1.023235
# 50%               -0.281243  -0.424602  -0.082306   0.343253  -0.500832
# 75%                0.070856   0.514139   0.543813   0.566118   1.237627
# 90%                0.251427   1.368129   0.707175   0.955073   1.826901
# 95%                0.257750   1.548360   0.997930   2.386805   2.091860
# 99%                0.262807   1.692545   1.230534   3.532191   2.303827

# %% [markdown]
# <a id="upload"></a>
# ## 3. Upload python function
#
# In this section you will learn how to upload the python function to the Cloud.

# %% [markdown]
# #### Custom software_specification
# Create new software specification based on default Python 3.9 environment extended by statsmodel package.

# %%
config_yml =\
"""
name: python310
channels:
  - conda-forge
  - nodefaults
dependencies:
  - statsmodels
prefix: /opt/anaconda3/envs/python310
"""

with open("config.yaml", "w", encoding="utf-8") as f:
    f.write(config_yml)

# %%
base_sw_spec_uid = client.software_specifications.get_uid_by_name("runtime-22.2-py3.10")

# %%
# !cat config.yaml
# Out:
# name: python39
# channels:
#   - empty
#   - nodefaults
# dependencies:
# - pip:
#   - statsmodels
#
# prefix: /opt/anaconda3/envs/python39

# %% [markdown]
# `config.yaml` file describes details of package extention. Now you need to store new package extention with APIClient.

# %%
meta_prop_pkg_extn = {
    client.package_extensions.ConfigurationMetaNames.NAME: "statsmodels env",
    client.package_extensions.ConfigurationMetaNames.DESCRIPTION: "Environment with statsmodels",
    client.package_extensions.ConfigurationMetaNames.TYPE: "conda_yml"
}

pkg_extn_details = client.package_extensions.store(meta_props=meta_prop_pkg_extn, file_path="config.yaml")
pkg_extn_uid = client.package_extensions.get_uid(pkg_extn_details)
pkg_extn_url = client.package_extensions.get_href(pkg_extn_details)
# Out:
# Creating package extensions
# SUCCESS

# %% [markdown]
# #### Create new software specification and add created package extention to it.

# %%
meta_prop_sw_spec = {
    client.software_specifications.ConfigurationMetaNames.NAME: "statsmodels software_spec",
    client.software_specifications.ConfigurationMetaNames.DESCRIPTION: "Software specification for statsmodels",
    client.software_specifications.ConfigurationMetaNames.BASE_SOFTWARE_SPECIFICATION: {"guid": base_sw_spec_uid}
}

sw_spec_details = client.software_specifications.store(meta_props=meta_prop_sw_spec)
sw_spec_uid = client.software_specifications.get_uid(sw_spec_details)

client.software_specifications.add_package_extension(sw_spec_uid, pkg_extn_uid)
# Out:
# SUCCESS
# 'SUCCESS'

# %% [markdown]
# #### Get the details of created software specification

# %%
client.software_specifications.get_details(sw_spec_uid)
# Out:
# {'metadata': {'name': 'statsmodels software_spec',
#   'asset_id': 'e81c0d6d-45cf-43d6-8047-d9858f0c74f8',
#   'href': '/v2/software_specifications/e81c0d6d-45cf-43d6-8047-d9858f0c74f8',
#   'asset_type': 'software_specification',
#   'created_at': '2022-04-12T09:33:32Z'},
#  'entity': {'software_specification': {'type': 'derived',
#    'display_name': 'statsmodels software_spec',
#    'base_software_specification': {'guid': '12b83a17-24d8-5082-900f-0ab31fbfd3cb',
#     'href': '/v2/software_specifications/12b83a17-24d8-5082-900f-0ab31fbfd3cb'},
#    'package_extensions': [{'metadata': {'space_id': '680a7515-620c-461f-9c6f-1f4c535bfc47',
#       'usage': {'last_updated_at': '2022-04-12T09:33:31Z',
#        'last_updater_id': 'IBMid-55000091VC',
#        'last_update_time': 1649756011121,
#        'last_accessed_at': '2022-04-12T09:33:31Z',
#        'last_access_time': 1649756011121,
#        'last_accessor_id': 'IBMid-55000091VC',
#        'access_count': 0},
#       'rov': {'mode': 0,
#        'collaborator_ids': {},
#        'member_roles': {'IBMid-55000091VC': {'user_iam_id': 'IBMid-55000091VC',
#          'roles': ['OWNER']}}},
#       'is_primary_attachment_downloadable': True,
#       'name': 'statsmodels env',
#       'description': 'Environment with statsmodels',
#       'tags': ['dsx'],
#       'asset_type': 'package_extension',
#       'origin_country': 'us',
#       'rating': 0,
#       'total_ratings': 0,
#       'catalog_id': 'ec8defc6-79d9-4989-9ec4-282b559d5a4e',
#       'created': 0,
#       'created_at': '2022-04-12T09:33:27Z',
#       'owner_id': 'IBMid-55000091VC',
#       'size': 125,
#       'version': 0,
#       'asset_state': 'available',
#       'asset_attributes': ['package_extension'],
#       'asset_id': 'f6fd8022-5def-4a68-8ba5-f73cc74bb723',
#       'asset_category': 'USER',
#       'creator_id': 'IBMid-55000091VC'},
#      'entity': {'package_extension': {'type': 'conda_yml',
#        'object_key': 'package_extension/statsmodels_env_Lfm3x4rP3.yml'}}}],
#    'software_configuration': {'included_packages': [{'name': 'abseil-cpp',
#       'version': '20210324.2'},
#      {'name': 'absl-py', 'version': '0.12.0'},
#      {'name': 'aiohttp', 'version': '3.8.1'},
#      {'name': 'aiosignal', 'version': '1.2.0'},
#      {'name': 'appdirs', 'version': '1.4.4'},
#      {'name': 'argon2-cffi', 'version': '20.1.0'},
#      {'name': 'arrow-cpp', 'version': '5.0.0'},
#      {'name': 'astropy', 'version': '4.3.1'},
#      {'name': 'astunparse', 'version': '1.6.3'},
#      {'name': 'async-timeout', 'version': '4.0.1'},
#      {'name': 'async_generator', 'version': '1.10'},
#      {'name': 'attrs', 'version': '21.2.0'},
#      {'name': 'autovizwidget', 'version': '0.18.0'},
#      {'name': 'av', 'version': '8.0.3'},
#      {'name': 'backcall', 'version': '0.2.0'},
#      {'name': 'beautifulsoup4', 'version': '4.10.0'},
#      {'name': 'biopython', 'version': '1.78'},
#      {'name': 'black', 'version': '19.10b0'},
#      {'name': 'blas', 'version': '1.0'},
#      {'name': 'bleach', 'version': '4.0.0'},
#      {'name': 'blinker', 'version': '1.4'},
#      {'name': 'blosc', 'version': '1.21.0'},
#      {'name': 'bokeh', 'version': '2.3.3'},
#      {'name': 'boto3', 'version': '1.18.21'},
#      {'name': 'botocore', 'version': '1.21.41'},
#      {'name': 'bottleneck', 'version': '1.3.2'},
#      {'name': 'brotli', 'version': '1.0.9'},
#      {'name': 'brotlipy', 'version': '0.7.0'},
#      {'name': 'brunsli', 'version': '0.1'},
#      {'name': 'bzip2', 'version': '1.0.8'},
#      {'name': 'c-ares', 'version': '1.17.1'},
#      {'name': 'ca-certificates', 'version': '2021.10.26'},
#      {'name': 'cached-property', 'version': '1.5.2'},
#      {'name': 'cachetools', 'version': '4.2.2'},
#      {'name': 'cairo', 'version': '1.16.0'},
#      {'name': 'certifi', 'version': '2021.10.8'},
#      {'name': 'cffi', 'version': '1.14.6'},
#      {'name': 'cfitsio', 'version': '3.470'},
#      {'name': 'charls', 'version': '2.2.0'},
#      {'name': 'charset-normalizer', 'version': '2.0.4'},
#      {'name': 'click', 'version': '8.0.3'},
#      {'name': 'cloudpickle', 'version': '1.6.0'},
#      {'name': 'cryptography', 'version': '3.4.8'},
#      {'name': 'cx_oracle', 'version': '8.3.0'},
#      {'name': 'cycler', 'version': '0.11.0'},
#      {'name': 'cytoolz', 'version': '0.11.0'},
#      {'name': 'dask-core', 'version': '2021.10.0'},
#      {'name': 'dataclasses', 'version': '0.8'},
#      {'name': 'debugpy', 'version': '1.5.1'},
#      {'name': 'decorator', 'version': '5.1.0'},
#      {'name': 'defusedxml', 'version': '0.7.1'},
#      {'name': 'dm-tree', 'version': '0.1.5'},
#      {'name': 'entrypoints', 'version': '0.3'},
#      {'name': 'et_xmlfile', 'version': '1.1.0'},
#      {'name': 'ffmpeg', 'version': '4.2.2'},
#      {'name': 'flatbuffers', 'version': '1.12.0'},
#      {'name': 'fontconfig', 'version': '2.13.1'},
#      {'name': 'fonttools', 'version': '4.25.0'},
#      {'name': 'freeglut', 'version': '3.0.0'},
#      {'name': 'freetds', 'version': '1.3.3'},
#      {'name': 'freetype', 'version': '2.11.0'},
#      {'name': 'frozenlist', 'version': '1.2.0'},
#      {'name': 'fsspec', 'version': '2021.10.1'},
#      {'name': 'future', 'version': '0.18.2'},
#      {'name': 'gast', 'version': '0.4.0'},
#      {'name': 'gflags', 'version': '2.2.2'},
#      {'name': 'giflib', 'version': '5.2.1'},
#      {'name': 'glib', 'version': '2.69.1'},
#      {'name': 'glog', 'version': '0.5.0'},
#      {'name': 'gmp', 'version': '6.2.1'},
#      {'name': 'gmpy2', 'version': '2.0.8'},
#      {'name': 'gnutls', 'version': '3.6.15'},
#      {'name': 'google-auth', 'version': '1.23.0'},
#      {'name': 'google-auth-oauthlib', 'version': '0.4.4'},
#      {'name': 'google-pasta', 'version': '0.2.0'},
#      {'name': 'googleapis-common-protos', 'version': '1.52.0'},
#      {'name': 'graphite2', 'version': '1.3.14'},
#      {'name': 'greenlet', 'version': '1.1.1'},
#      {'name': 'grpc-cpp', 'version': '1.41.0'},
#      {'name': 'grpcio', 'version': '1.42.0'},
#      {'name': 'h5py', 'version': '3.2.1'},
#      {'name': 'harfbuzz', 'version': '1.8.8'},
#      {'name': 'hdf5', 'version': '1.10.6'},
#      {'name': 'hdijupyterutils', 'version': '0.19.0'},
#      {'name': 'html5lib', 'version': '1.1'},
#      {'name': 'icu', 'version': '58.2'},
#      {'name': 'idna', 'version': '3.3'},
#      {'name': 'imagecodecs', 'version': '2021.8.26'},
#      {'name': 'imageio', 'version': '2.9.0'},
#      {'name': 'importlib-metadata', 'version': '4.8.2'},
#      {'name': 'importlib_metadata', 'version': '4.8.2'},
#      {'name': 'iniconfig', 'version': '1.1.1'},
#      {'name': 'ipykernel', 'version': '6.4.1'},
#      {'name': 'ipython', 'version': '7.29.0'},
#      {'name': 'ipython_genutils', 'version': '0.2.0'},
#      {'name': 'ipywidgets', 'version': '7.6.5'},
#      {'name': 'jasper', 'version': '2.0.14'},
#      {'name': 'jedi', 'version': '0.18.0'},
#      {'name': 'jinja2', 'version': '3.0.2'},
#      {'name': 'jmespath', 'version': '0.10.0'},
#      {'name': 'joblib', 'version': '0.17.0'},
#      {'name': 'jpeg', 'version': '9d'},
#      {'name': 'jsonschema', 'version': '3.2.0'},
#      {'name': 'jupyter', 'version': '1.0.0'},
#      {'name': 'jupyter_client', 'version': '7.0.6'},
#      {'name': 'jupyter_console', 'version': '6.4.0'},
#      {'name': 'jupyter_core', 'version': '4.9.1'},
#      {'name': 'jupyterlab_pygments', 'version': '0.1.2'},
#      {'name': 'jupyterlab_widgets', 'version': '1.0.0'},
#      {'name': 'jxrlib', 'version': '1.1'},
#      {'name': 'keras', 'version': '2.7.0'},
#      {'name': 'keras-preprocessing', 'version': '1.1.2'},
#      {'name': 'kiwisolver', 'version': '1.3.1'},
#      {'name': 'krb5', 'version': '1.19.2'},
#      {'name': 'lame', 'version': '3.100'},
#      {'name': 'lcms2', 'version': '2.12'},
#      {'name': 'ld_impl_linux-64', 'version': '2.35.1'},
#      {'name': 'lerc', 'version': '3.0'},
#      {'name': 'leveldb', 'version': '1.20'},
#      {'name': 'libaec', 'version': '1.0.4'},
#      {'name': 'libclang', 'version': '10.0.1'},
#      {'name': 'libcurl', 'version': '7.80.0'},
#      {'name': 'libdeflate', 'version': '1.8'},
#      {'name': 'libedit', 'version': '3.1.20210910'},
#      {'name': 'libev', 'version': '4.33'},
#      {'name': 'libevent', 'version': '2.1.8'},
#      {'name': 'libffi', 'version': '3.3'},
#      {'name': 'libgcc-ng', 'version': '9.3.0'},
#      {'name': 'libgfortran-ng', 'version': '7.5.0'},
#      {'name': 'libgfortran4', 'version': '7.5.0'},
#      {'name': 'libglu', 'version': '9.0.0'},
#      {'name': 'libgomp', 'version': '9.3.0'},
#      {'name': 'libidn2', 'version': '2.3.2'},
#      {'name': 'liblightgbm', 'version': '3.3.1'},
#      {'name': 'libllvm10', 'version': '10.0.1'},
#      {'name': 'libllvm11', 'version': '11.1.0'},
#      {'name': 'libnghttp2', 'version': '1.46.0'},
#      {'name': 'libopenblas', 'version': '0.3.13'},
#      {'name': 'libopencv', 'version': '4.5.3'},
#      {'name': 'libopus', 'version': '1.3.1'},
#      {'name': 'libpng', 'version': '1.6.37'},
#      {'name': 'libpq', 'version': '12.9'},
#      {'name': 'libprotobuf', 'version': '3.14.0'},
#      {'name': 'libsodium', 'version': '1.0.18'},
#      {'name': 'libssh2', 'version': '1.9.0'},
#      {'name': 'libstdcxx-ng', 'version': '9.3.0'},
#      {'name': 'libtasn1', 'version': '4.16.0'},
#      {'name': 'libthrift', 'version': '0.15.0'},
#      {'name': 'libtiff', 'version': '4.2.0'},
#      {'name': 'libunistring', 'version': '0.9.10'},
#      {'name': 'libutf8proc', 'version': '2.6.1'},
#      {'name': 'libuuid', 'version': '1.0.3'},
#      {'name': 'libvpx', 'version': '1.7.0'},
#      {'name': 'libwebp', 'version': '1.2.0'},
#      {'name': 'libwebp-base', 'version': '1.2.0'},
#      {'name': 'libxcb', 'version': '1.14'},
#      {'name': 'libxgboost', 'version': '1.5.1'},
#      {'name': 'libxml2', 'version': '2.9.12'},
#      {'name': 'libxslt', 'version': '1.1.34'},
#      {'name': 'libzopfli', 'version': '1.0.3'},
#      {'name': 'lightgbm', 'version': '3.3.1'},
#      {'name': 'llvmlite', 'version': '0.37.0'},
#      {'name': 'lmdb', 'version': '0.9.29'},
#      {'name': 'locket', 'version': '0.2.1'},
#      {'name': 'lxml', 'version': '4.7.1'},
#      {'name': 'lz4-c', 'version': '1.9.3'},
#      {'name': 'lzo', 'version': '2.10'},
#      {'name': 'markdown', 'version': '3.3.3'},
#      {'name': 'markupsafe', 'version': '2.0.1'},
#      {'name': 'matplotlib', 'version': '3.5.0'},
#      {'name': 'matplotlib-base', 'version': '3.5.0'},
#      {'name': 'matplotlib-inline', 'version': '0.1.2'},
#      {'name': 'mistune', 'version': '0.8.4'},
#      {'name': 'mock', 'version': '4.0.3'},
#      {'name': 'mpc', 'version': '1.1.0'},
#      {'name': 'mpfr', 'version': '4.0.2'},
#      {'name': 'mpi', 'version': '1.0'},
#      {'name': 'mpmath', 'version': '1.2.1'},
#      {'name': 'multidict', 'version': '5.2.0'},
#      {'name': 'munkres', 'version': '1.1.4'},
#      {'name': 'mypy_extensions', 'version': '0.4.3'},
#      {'name': 'nbclient', 'version': '0.5.3'},
#      {'name': 'nbconvert', 'version': '6.1.0'},
#      {'name': 'nbformat', 'version': '5.1.3'},
#      {'name': 'ncurses', 'version': '6.3'},
#      {'name': 'nest-asyncio', 'version': '1.5.1'},
#      {'name': 'nettle', 'version': '3.7.3'},
#      {'name': 'networkx', 'version': '2.6.3'},
#      {'name': 'nltk', 'version': '3.6.5'},
#      {'name': 'nose', 'version': '1.3.7'},
#      {'name': 'notebook', 'version': '6.4.6'},
#      {'name': 'numactl', 'version': '2.0.12'},
#      {'name': 'numba', 'version': '0.54.1'},
#      {'name': 'numexpr', 'version': '2.8.1'},
#      {'name': 'numpy', 'version': '1.20.3'},
#      {'name': 'numpy-base', 'version': '1.20.3'},
#      {'name': 'oauthlib', 'version': '3.1.1'},
#      {'name': 'olefile', 'version': '0.46'},
#      {'name': 'onnx', 'version': '1.10.2'},
#      {'name': 'onnxconverter-common', 'version': '1.9.0'},
#      {'name': 'opencv', 'version': '4.5.3'},
#      {'name': 'openh264', 'version': '2.1.1'},
#      {'name': 'openjpeg', 'version': '2.4.0'},
#      {'name': 'openmpi', 'version': '4.1.1'},
#      {'name': 'openpyxl', 'version': '3.0.9'},
#      {'name': 'openssl', 'version': '1.1.1m'},
#      {'name': 'opt_einsum', 'version': '3.3.0'},
#      {'name': 'orc', 'version': '1.7.2'},
#      {'name': 'packaging', 'version': '21.3'},
#      {'name': 'pandas', 'version': '1.3.4'},
#      {'name': 'pandocfilters', 'version': '1.4.3'},
#      {'name': 'parso', 'version': '0.8.3'},
#      {'name': 'partd', 'version': '1.2.0'},
#      {'name': 'pathspec', 'version': '0.7.0'},
#      {'name': 'patsy', 'version': '0.5.2'},
#      {'name': 'pcre', 'version': '8.45'},
#      {'name': 'pexpect', 'version': '4.8.0'},
#      {'name': 'pickleshare', 'version': '0.7.5'},
#      {'name': 'pillow', 'version': '8.4.0'},
#      {'name': 'pip', 'version': '21.2.4'},
#      {'name': 'pixman', 'version': '0.40.0'},
#      {'name': 'plotly', 'version': '5.1.0'},
#      {'name': 'pluggy', 'version': '1.0.0'},
#      {'name': 'portpicker', 'version': '1.3.1'},
#      {'name': 'prometheus_client', 'version': '0.12.0'},
#      {'name': 'prompt-toolkit', 'version': '3.0.20'},
#      {'name': 'prompt_toolkit', 'version': '3.0.20'},
#      {'name': 'protobuf', 'version': '3.14.0'},
#      {'name': 'psutil', 'version': '5.8.0'},
#      {'name': 'psycopg2', 'version': '2.8.6'},
#      {'name': 'ptyprocess', 'version': '0.7.0'},
#      {'name': 'py', 'version': '1.10.0'},
#      {'name': 'py-opencv', 'version': '4.5.3'},
#      {'name': 'pyarrow', 'version': '5.0.0'},
#      {'name': 'pyasn1', 'version': '0.4.8'},
#      {'name': 'pyasn1-modules', 'version': '0.2.8'},
#      {'name': 'pycparser', 'version': '2.21'},
#      {'name': 'pycryptodome', 'version': '3.10.1'},
#      {'name': 'pydeprecate', 'version': '0.3.2'},
#      {'name': 'pyerfa', 'version': '2.0.0'},
#      {'name': 'pygments', 'version': '2.10.0'},
#      {'name': 'pyjwt', 'version': '2.1.0'},
#      {'name': 'pymssql', 'version': '2.1.4'},
#      {'name': 'pyodbc', 'version': '4.0.31'},
#      {'name': 'pyopenssl', 'version': '21.0.0'},
#      {'name': 'pyparsing', 'version': '3.0.4'},
#      {'name': 'pyrsistent', 'version': '0.18.0'},
#      {'name': 'pysocks', 'version': '1.7.1'},
#      {'name': 'pyspnego', 'version': '0.3.1'},
#      {'name': 'pytables', 'version': '3.6.1'},
#      {'name': 'pytest', 'version': '6.2.5'},
#      {'name': 'python', 'version': '3.9.7'},
#      {'name': 'python-clang', 'version': '10.0.1'},
#      {'name': 'python-dateutil', 'version': '2.8.2'},
#      {'name': 'python-flatbuffers', 'version': '1.12'},
#      {'name': 'pytorch-base', 'version': '1.10.1'},
#      {'name': 'pytorch-cpu', 'version': '1.10.1'},
#      {'name': 'pytorch-lightning', 'version': '1.5.7'},
#      {'name': 'pytz', 'version': '2021.3'},
#      {'name': 'pywavelets', 'version': '1.1.1'},
#      {'name': 'pyyaml', 'version': '5.4.1'},
#      {'name': 'pyzmq', 'version': '22.3.0'},
#      {'name': 'qtconsole', 'version': '5.1.1'},
#      {'name': 'qtpy', 'version': '1.10.0'},
#      {'name': 're2', 'version': '2020.11.01'},
#      {'name': 'readline', 'version': '8.1'},
#      {'name': 'regex', 'version': '2021.11.2'},
#      {'name': 'requests', 'version': '2.26.0'},
#      {'name': 'requests-kerberos', 'version': '0.14.0'},
#      {'name': 'requests-oauthlib', 'version': '1.3.0'},
#      {'name': 'rsa', 'version': '4.7.2'},
#      {'name': 'ruamel.yaml', 'version': '0.16.12'},
#      {'name': 'ruamel.yaml.clib', 'version': '0.2.6'},
#      {'name': 's3transfer', 'version': '0.5.0'},
#      {'name': 'scikit-image', 'version': '0.18.3'},
#      {'name': 'scikit-learn', 'version': '1.0.2'},
#      {'name': 'scipy', 'version': '1.7.3'},
#      {'name': 'seaborn', 'version': '0.11.2'},
#      {'name': 'send2trash', 'version': '1.8.0'},
#      {'name': 'sentencepiece', 'version': '0.1.96'},
#      {'name': 'setuptools', 'version': '58.0.4'},
#      {'name': 'six', 'version': '1.15.0'},
#      {'name': 'skl2onnx', 'version': '1.10.3'},
#      {'name': 'snapml', 'version': '1.8.3'},
#      {'name': 'snappy', 'version': '1.1.8'},
#      {'name': 'snowballstemmer', 'version': '2.2.0'},
#      {'name': 'sortedcontainers', 'version': '2.4.0'},
#      {'name': 'soupsieve', 'version': '2.3.1'},
#      {'name': 'sparkmagic', 'version': '0.19.0'},
#      {'name': 'sqlalchemy', 'version': '1.4.27'},
#      {'name': 'sqlite', 'version': '3.37.0'},
#      {'name': 'statsmodels', 'version': '0.12.2'},
#      {'name': 'sympy', 'version': '1.9'},
#      {'name': 'tabulate', 'version': '0.8.9'},
#      {'name': 'tbb', 'version': '2021.4.0'},
#      {'name': 'tenacity', 'version': '8.0.1'},
#      {'name': 'tensorboard', 'version': '2.7.0'},
#      {'name': 'tensorboard-data-server', 'version': '0.6.1'},
#      {'name': 'tensorboard-plugin-wit', 'version': '1.6.0'},
#      {'name': 'tensorflow-addons', 'version': '0.15.0'},
#      {'name': 'tensorflow-base', 'version': '2.7.0'},
#      {'name': 'tensorflow-cpu', 'version': '2.7.0'},
#      {'name': 'tensorflow-estimator', 'version': '2.7.0'},
#      {'name': 'tensorflow-hub', 'version': '0.12.0'},
#      {'name': 'tensorflow-io-gcs-filesystem', 'version': '0.23.1'},
#      {'name': 'tensorflow-metadata', 'version': '1.5.0'},
#      {'name': 'tensorflow-model-optimization', 'version': '0.7.0'},
#      {'name': 'tensorflow-probability', 'version': '0.15.0'},
#      {'name': 'tensorflow-text', 'version': '2.7.3'},
#      {'name': 'termcolor', 'version': '1.1.0'},
#      {'name': 'terminado', 'version': '0.9.4'},
#      {'name': 'testpath', 'version': '0.5.0'},
#      {'name': 'tf2onnx', 'version': '1.9.3'},
#      {'name': 'threadpoolctl', 'version': '2.2.0'},
#      {'name': 'tifffile', 'version': '2021.7.2'},
#      {'name': 'tk', 'version': '8.6.11'},
#      {'name': 'toml', 'version': '0.10.2'},
#      {'name': 'toolz', 'version': '0.11.2'},
#      {'name': 'torchmetrics', 'version': '0.6.2'},
#      {'name': 'torchtext-base', 'version': '0.11.1'},
#      {'name': 'torchvision-base', 'version': '0.11.2'},
#      {'name': 'tornado', 'version': '6.1'},
#      {'name': 'tqdm', 'version': '4.62.3'},
#      {'name': 'traitlets', 'version': '5.1.1'},
#      {'name': 'typed-ast', 'version': '1.4.3'},
#      {'name': 'typeguard', 'version': '2.12.0'},
#      {'name': 'typing-extensions', 'version': '3.7.4.3'},
#      {'name': 'typing_extensions', 'version': '3.7.4.3'},
#      {'name': 'tzdata', 'version': '2021e'},
#      {'name': 'unixodbc', 'version': '2.3.9'},
#      {'name': 'urllib3', 'version': '1.26.7'},
#      {'name': 'wcwidth', 'version': '0.2.5'},
#      {'name': 'webencodings', 'version': '0.5.1'},
#      {'name': 'werkzeug', 'version': '2.0.2'},
#      {'name': 'wheel', 'version': '0.37.0'},
#      {'name': 'widgetsnbextension', 'version': '3.5.1'},
#      {'name': 'wrapt', 'version': '1.12.1'},
#      {'name': 'x264', 'version': '1!157.20191217'},
#      {'name': 'xgboost', 'version': '1.5.1'},
#      {'name': 'xlrd', 'version': '2.0.1'},
#      {'name': 'xlsxwriter', 'version': '3.0.2'},
#      {'name': 'xz', 'version': '5.2.5'},
#      {'name': 'yaml', 'version': '0.2.5'},
#      {'name': 'yarl', 'version': '1.6.3'},
#      {'name': 'zeromq', 'version': '4.3.4'},
#      {'name': 'zfp', 'version': '0.5.5'},
#      {'name': 'zipp', 'version': '3.6.0'},
#      {'name': 'zlib', 'version': '1.2.11'},
#      {'name': 'zstd', 'version': '1.4.9'},
#      {'name': 'azure-core', 'version': '1.21.0'},
#      {'name': 'azure-cosmos', 'version': '4.2.0'},
#      {'name': 'ca-data-connector', 'version': '11.2.0'},
#      {'name': 'cassandra-driver', 'version': '3.25.0'},
#      {'name': 'cplex', 'version': '20.1.0.2'},
#      {'name': 'docplex', 'version': '2.22.213'},
#      {'name': 'dsx-core-utils', 'version': '0.3'},
#      {'name': 'gensim', 'version': '3.8.3'},
#      {'name': 'geographiclib', 'version': '1.52'},
#      {'name': 'geomet', 'version': '0.2.1.post1'},
#      {'name': 'geopy', 'version': '2.2.0'},
#      {'name': 'greenery', 'version': '3.3.2'},
#      {'name': 'hadoop-lib-utils', 'version': '0.2'},
#      {'name': 'hyperopt', 'version': '0.2.5'},
#      {'name': 'ibm-cloud-sdk-core', 'version': '3.10.1'},
#      {'name': 'ibm-cos-sdk', 'version': '2.11.0'},
#      {'name': 'ibm-cos-sdk-core', 'version': '2.11.0'},
#      {'name': 'ibm-cos-sdk-s3transfer', 'version': '2.11.0'},
#      {'name': 'ibm-db', 'version': '3.1.0'},
#      {'name': 'ibm-db-sa', 'version': '0.3.7'},
#      {'name': 'ibm-watson-openscale', 'version': '3.0.12'},
#      {'name': 'ibm-watson-studio-lib', 'version': '3.0.7'},
#      {'name': 'itc-utils', 'version': '0.1.10'},
#      {'name': 'jaydebeapi', 'version': '1.2.3'},
#      {'name': 'jpype1', 'version': '1.3.0'},
#      {'name': 'jsonref', 'version': '0.2'},
#      {'name': 'jsonsubschema', 'version': '0.0.5'},
#      {'name': 'lale', 'version': '0.6.0'},
#      {'name': 'lomond', 'version': '0.3.3'},
#      {'name': 'mysql-connector-python', 'version': '8.0.25'},
#      {'name': 'portion', 'version': '2.2.0'},
#      {'name': 'project-lib', 'version': '2.0.4'},
#      {'name': 'python-graphviz', 'version': '0.19'},
#      {'name': 'smart-open', 'version': '5.2.1'}],
#     'platform': {'name': 'python', 'version': '3.9'}}}}}

# %% [markdown]
# #### Store the function

# %%
meta_props = {
    client.repository.FunctionMetaNames.NAME: "statsmodels function",
    client.repository.FunctionMetaNames.SOFTWARE_SPEC_UID: sw_spec_uid
}

function_details = client.repository.store_function(meta_props=meta_props, function=deployable_callable)
function_id = client.repository.get_function_id(function_details)

# %% [markdown]
# #### Get function details

# %%
client.repository.get_details(function_id)
# Out:
# {'entity': {'software_spec': {'id': 'e81c0d6d-45cf-43d6-8047-d9858f0c74f8',
#    'name': 'statsmodels software_spec'},
#   'type': 'python'},
#  'metadata': {'created_at': '2022-04-12T09:33:47.753Z',
#   'id': '1211c5af-3f0e-475a-927c-30114868bafa',
#   'modified_at': '2022-04-12T09:33:52.512Z',
#   'name': 'statsmodels function',
#   'owner': 'IBMid-55000091VC',
#   'space_id': '680a7515-620c-461f-9c6f-1f4c535bfc47'},
#  'system': {'warnings': []}}

# %% [markdown]
# **Note:** You can see that function is successfully stored in Watson Machine Learning Service.

# %%
client.repository.list_functions()

# %% [markdown]
# <a id="deploy"></a>
# ## 4. Create online deployment
# You can use commands bellow to create online deployment for stored function (web service).

# %% [markdown]
# #### Create online deployment of a python function

# %%
metadata = {
    client.deployments.ConfigurationMetaNames.NAME: "Deployment of statsmodels function",
    client.deployments.ConfigurationMetaNames.ONLINE: {}
}

function_deployment = client.deployments.create(function_id, meta_props=metadata)
# Out:
# #######################################################################################
#
# Synchronous deployment creation for uid: '1211c5af-3f0e-475a-927c-30114868bafa' started
#
# #######################################################################################
#
#
# initializing
# Note: online_url is deprecated and will be removed in a future release. Use serving_urls instead.
# .........
# ready
#
#
# ------------------------------------------------------------------------------------------------
# Successfully finished deployment creation, deployment_uid='9b723c1c-5d8f-4f1f-bc4e-bf7d582a4ba6'
# ------------------------------------------------------------------------------------------------

# %%
client.deployments.list()

# %% [markdown]
# Get deployment id.

# %%
deployment_id = client.deployments.get_id(function_deployment)
print(deployment_id)
# Out:
# 9b723c1c-5d8f-4f1f-bc4e-bf7d582a4ba6

# %% [markdown]
# <a id="score"></a>
# ## 5. Scoring
#
# You can send new scoring records to web-service deployment using `score` method.

# %%
scoring_payload = {
    "input_data": [{
        'values': data
    }]
}

# %%
predictions = client.deployments.score(deployment_id, scoring_payload)
print(data_description["predictions"][0]["values"])
# Out:
#                           0          1          2          3          4  \
# nobs              10.000000  10.000000  10.000000  10.000000  10.000000
# missing            0.000000   0.000000   0.000000   0.000000   0.000000
# mean               0.226671   0.118863   0.296608   0.018030  -0.059889
# std_err            0.078214   0.109682   0.077958   0.069102   0.099104
# upper_ci           0.379969   0.333837   0.449404   0.153467   0.134352
# lower_ci           0.073374  -0.096110   0.143813  -0.117407  -0.254130
# std                0.782143   1.096823   0.779584   0.691019   0.991042
# iqr                1.138703   0.979375   1.111591   0.625231   1.315194
# iqr_normal         0.844122   0.726012   0.824023   0.463485   0.974954
# mad                0.623878   0.774813   0.618962   0.513830   0.799944
# mad_normal         0.781915   0.971084   0.775754   0.643991   1.002581
# coef_var           3.450557   9.227584   2.628330  38.326234 -16.547990
# range              2.289961   3.407891   2.370988   2.429216   3.152545
# max                1.216507   1.544682   1.624286   1.266127   1.517858
# min               -1.073454  -1.863208  -0.746702  -1.163089  -1.634687
# skew              -0.180136  -0.472191   0.300966   0.263092   0.206849
# kurtosis           1.900409   2.384448   1.984736   2.702869   2.043656
# jarque_bera        0.557873   0.529483   0.580451   0.152149   0.452392
# jarque_bera_pval   0.756588   0.767404   0.748095   0.926747   0.797562
# mode              -1.073454  -1.863208  -0.746702  -1.163089  -1.634687
# mode_freq          0.100000   0.100000   0.100000   0.100000   0.100000
# median             0.131746   0.126305   0.196596  -0.075777  -0.289048
# 1%                -1.035160  -1.819212  -0.736463  -1.097474  -1.557357
# 5%                -0.881982  -1.643226  -0.695507  -0.835012  -1.248039
# 10%               -0.690509  -1.423244  -0.644312  -0.506934  -0.861391
# 25%               -0.265950  -0.093626  -0.179451  -0.372709  -0.669090
# 50%                0.131746   0.126305   0.196596  -0.075777  -0.289048
# 75%                0.872753   0.885749   0.932140   0.252522   0.646103
# 90%                1.207454   1.400947   1.147246   0.910790   1.227843
# 95%                1.211980   1.472815   1.385766   1.088459   1.372850
# 99%                1.215602   1.530309   1.576582   1.230594   1.488856
#
#                           5          6          7          8          9
# nobs              10.000000  10.000000  10.000000  10.000000  10.000000
# missing            0.000000   0.000000   0.000000   0.000000   0.000000
# mean              -0.483244  -0.254453   0.058877   0.426315   0.070967
# std_err            0.096181   0.121981   0.067393   0.132276   0.142787
# upper_ci          -0.294733  -0.015374   0.190965   0.685572   0.350825
# lower_ci          -0.671756  -0.493532  -0.073210   0.167058  -0.208891
# std                0.961811   1.219812   0.673929   1.322764   1.427874
# iqr                0.702320   1.694391   1.086336   0.818691   2.260862
# iqr_normal         0.520631   1.256054   0.805302   0.606896   1.675980
# mad                0.595403   0.992851   0.548831   0.775163   1.241234
# mad_normal         0.746228   1.244354   0.687858   0.971523   1.555656
# coef_var          -1.990319  -4.793857  11.446314   3.102789  20.120208
# range              3.290262   3.729499   2.020311   4.731702   4.155165
# max                0.264072   1.728591   1.288685   3.818537   2.356818
# min               -3.026190  -2.000908  -0.731626  -0.913165  -1.798347
# skew              -2.016374   0.280287   0.361658   1.723070   0.344541
# kurtosis           6.145500   1.926644   2.092429   5.591678   1.669951
# jarque_bera       10.898847   0.610973   0.561196   7.746946   0.934943
# jarque_bera_pval   0.004299   0.736765   0.755332   0.020786   0.626585
# mode              -3.026190  -2.000908  -0.731626  -0.913165  -1.798347
# mode_freq          0.100000   0.100000   0.100000   0.100000   0.100000
# median            -0.281243  -0.424602  -0.082306   0.343253  -0.500832
# 1%                -2.818282  -1.945829  -0.727344  -0.906817  -1.742649
# 5%                -1.986648  -1.725515  -0.710218  -0.881427  -1.519857
# 10%               -0.947106  -1.450121  -0.688811  -0.849689  -1.241366
# 25%               -0.631465  -1.180252  -0.542524  -0.252573  -1.023235
# 50%               -0.281243  -0.424602  -0.082306   0.343253  -0.500832
# 75%                0.070856   0.514139   0.543813   0.566118   1.237627
# 90%                0.251427   1.368129   0.707175   0.955073   1.826901
# 95%                0.257750   1.548360   0.997930   2.386805   2.091860
# 99%                0.262807   1.692545   1.230534   3.532191   2.303827

# %% [markdown]
# <a id="cleanup"></a>
# ## 6. Clean up

# %% [markdown]
# If you want to clean up all created assets:
# - experiments
# - trainings
# - pipelines
# - model definitions
# - models
# - functions
# - deployments
#
# see the steps in this sample [notebook](https://github.com/IBM/watson-machine-learning-samples/blob/master/cloud/notebooks/python_sdk/instance-management/Machine%20Learning%20artifacts%20management.ipynb).

# %% [markdown]
# <a id="summary"></a>
# ## 7. Summary and next steps

# %% [markdown]
#  You successfully completed this notebook! You learned how to use Watson Machine Learning for function deployment and scoring with custom software_spec.
#  Check out our [Online Documentation](https://dataplatform.cloud.ibm.com/docs/content/wsj/getting-started/welcome-main.html?context=analytics) for more samples, tutorials, documentation, how-tos, and blog posts.

# %% [markdown]
# ### Author
#
# **Jan Sołtysik** Intern in Watson Machine Learning.

# %% [markdown]
# Copyright © 2020, 2021, 2022 IBM. This notebook and its source code are released under the terms of the MIT License.
